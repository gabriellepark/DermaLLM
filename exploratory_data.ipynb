# %% [markdown]
# <a href="https://colab.research.google.com/github/gaby-chu/DermaLLM/blob/main/aml_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
product_data = pd.read_csv('/content/drive/MyDrive/aml/product_info.csv')

# %%
product_data.columns
# Out:
# Index(['product_id', 'product_name', 'brand_id', 'brand_name', 'loves_count',
#        'rating', 'reviews', 'size', 'variation_type', 'variation_value',
#        'variation_desc', 'ingredients', 'price_usd', 'value_price_usd',
#        'sale_price_usd', 'limited_edition', 'new', 'online_only',
#        'out_of_stock', 'sephora_exclusive', 'highlights', 'primary_category',
#        'secondary_category', 'tertiary_category', 'child_count',
#        'child_max_price', 'child_min_price'],
#       dtype='object')

# %%
product_data['primary_category'].unique()
# Out:
# array(['Fragrance', 'Bath & Body', 'Mini Size', 'Hair', 'Makeup',
#        'Skincare', 'Tools & Brushes', 'Men', 'Gifts'], dtype=object)

# %%
product_data['secondary_category'].unique()
# Out:
# array(['Value & Gift Sets', 'Women', 'Body Moisturizers', 'Fragrance',
#        'Men', 'Candles & Home Scents', 'Body Care',
#        'Hair Styling & Treatments', 'Shampoo & Conditioner', 'Mini Size',
#        'Lip', 'Moisturizers', 'Treatments', 'Eye Care',
#        'Lip Balms & Treatments', 'Sunscreen', 'Cleansers', 'Masks',
#        'Skincare', 'Face', 'Eye', 'Cheek', 'Hair', 'Tools',
#        'Brushes & Applicators', 'Makeup Palettes', 'Beauty Tools',
#        'Accessories', 'Makeup', 'Bath & Shower', 'Wellness',
#        'High Tech Tools', 'Shop by Concern', nan, 'Self Tanners',
#        'Shaving', 'Hair Tools', 'Nail', 'Beauty Accessories',
#        'Beauty Supplements', 'Other Needs', 'Bath & Body'], dtype=object)

# %%
product_data['highlights'].unique()
# Out:
# array(["['Unisex/ Genderless Scent', 'Warm &Spicy Scent', 'Woody & Earthy Scent', 'Fresh Scent']",
#        "['Unisex/ Genderless Scent', 'Layerable Scent', 'Warm &Spicy Scent']",
#        "['Unisex/ Genderless Scent', 'Layerable Scent', 'Woody & Earthy Scent']",
#        ...,
#        "['Best for Oily, Combo, Normal Skin', 'Without Parabens', 'Without Mineral Oil', 'Matte Finish', 'Salicylic Acid']",
#        "['Natural Finish', 'Without Mineral Oil', 'Without Parabens']",
#        "['Hyaluronic Acid', 'High Shine Finish', 'Plumping', 'Hydrating', 'Medium Coverage']"],
#       dtype=object)

# %%
skincare = product_data[product_data['primary_category'] == "Skincare"]
print(skincare.iloc[1])
skincare.iloc[1]['ingredients']
# Out:
# product_id                                                      P421277
# product_name                               GENIUS Liquid Collagen Serum
# brand_id                                                           6018
# brand_name                                                     Algenist
# loves_count                                                       67870
# rating                                                           4.0259
# reviews                                                          1159.0
# size                                                      1 oz  / 30 mL
# variation_type                                                     Size
# variation_value                                           1 oz  / 30 mL
# variation_desc                                                      NaN
# ingredients           ['Collagen (Vegan)*, Water (Aqua, Eau), Propan...
# price_usd                                                         115.0
# ...

# %%
skincare['highlights'].unique()
# Out:
# array(["['Vegan', 'Good for: Loss of firmness', 'Collagen', 'Hypoallergenic', 'Without Parabens', 'Best for Dry, Combo, Normal Skin']",
#        nan,
#        "['Vegan', 'Good for: Loss of firmness', 'Plumping', 'Collagen', 'Hypoallergenic', 'Best for Dry, Combo, Normal Skin']",
#        ...,
#        "['Vegan', 'Hyaluronic Acid', 'Clean at Sephora', 'Hydrating', 'Good for: Dryness', 'Best for Dry, Combo, Normal Skin']",
#        "['Vegan', 'Good for: Pores', 'Clean + Planet Positive', 'Good for: Acne/Blemishes', 'Best for Oily, Combo, Normal Skin', 'Without Sulfates SLS & SLES']",
#        "['Vegan', 'Good for: Dullness/Uneven Texture', 'Vitamin C', 'Plumping', 'Clean at Sephora', 'Hydrating']"],
#       dtype=object)

# %%
review1 = pd.read_csv('/content/drive/MyDrive/aml/reviews_0-250.csv', engine='python', on_bad_lines='warn')
# Out:
# /tmp/ipython-input-1695459337.py:1: ParserWarning: Skipping line 200391: unexpected end of data
#
#   review1 = pd.read_csv('/content/drive/MyDrive/aml/reviews_0-250.csv', engine='python', on_bad_lines='warn')

# %%
review1[review1['brand_name'] == "LANEIGE"]
# Out:
#         Unnamed: 0    author_id  rating  is_recommended  helpfulness  \
# 1                1  31423088263       1             0.0          NaN
# 2                2   5061282401       5             1.0          NaN
# 3                3   6083038851       5             1.0          NaN
# 4                4  47056667835       5             1.0          NaN
# 5                5  42802569154       4             1.0     1.000000
# ...            ...          ...     ...             ...          ...
# 188537      188537   6676094382       5             1.0          NaN
# 188538      188538  10854508312       5             1.0     0.800000
# 188539      188539   7657064307       4             1.0     0.789916
# 188540      188540   9148182545       5             1.0          NaN
# 188541      188541   5267824074       4             1.0     0.915789
#
#         total_feedback_count  total_neg_feedback_count  \
# 1                          0                         0
# ...

# %%
review1.columns
# Out:
# Index(['Unnamed: 0', 'author_id', 'rating', 'is_recommended', 'helpfulness',
#        'total_feedback_count', 'total_neg_feedback_count',
#        'total_pos_feedback_count', 'submission_time', 'review_text',
#        'review_title', 'skin_tone', 'eye_color', 'skin_type', 'hair_color',
#        'product_id', 'product_name', 'brand_name', 'price_usd'],
#       dtype='object')
