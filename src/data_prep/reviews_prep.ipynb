# %%
from google.colab import drive
import os

# Mount Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import ast
import datetime
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Functions definitions

# %%
# For data exploration
def data_summary(df, cat_cols, num_cols, describe_pts=[0.1, .2,.25,.5, .75, .9, .95, .99]):
    print("Data shape: ", df.shape)
    print("Data columns: ", df.columns)

    # Get hit rates for variables in the dataset, evaluate missing values proportions
    hr = df.notnull().mean().reset_index().rename(columns={'index':'variable',0:'hit_rate'})

    # Get data types
    df_types = df.dtypes.reset_index().rename(columns={'index':'variable',0:'data_type'})

    # Put info in same data add
    variable_summary = pd.merge(df_types, hr, on=['variable'], how='left', suffixes=('','_hr'))

    # Get value counts for categorical variables
    cat_vars_summary = pd.DataFrame(columns=['variable_name','unique_values','counts'])
    for col in cat_cols:
        new_counts = df[col].value_counts(dropna=False).rename_axis('unique_values').to_frame('counts').reset_index()
        new_counts.insert(loc=0, column='variable_name', value=col)
        cat_vars_summary = pd.concat([cat_vars_summary, new_counts], ignore_index = True)

    cont_vars_summary = df[num_cols].describe(describe_pts).reset_index().rename(columns={'index':'stats'})

    # Get correlation matrix for continuous variables
    df_corr = df[num_cols].corr()

    return variable_summary, cat_vars_summary, cont_vars_summary, df_corr

# %%
def summarize(df: pd.DataFrame, level: list, cols: list) -> pd.DataFrame:
    aggregations = {}
    for col in cols:
        aggregations.update({col:  [("Min", "min"), ("Max", "max"), ("Mean", "mean"), ("Sum","sum")]})

    df_agg = df.groupby(level).agg(aggregations).reset_index()

    # Renaming columns
    df_agg.columns = ["_".join(col).strip() for col in df_agg.columns.values]

    return df_agg

# %% [markdown]
# ### Data Import

# %%
# Data dictionary can be found here: https://www.kaggle.com/datasets/nadyinky/sephora-products-and-skincare-reviews

# %%
# Navigate to your data directory
# data_dir = '/content/drive/MyDrive/Colab Notebooks/DermaLLM/data/'
data_dir = '/content/drive/MyDrive/Colab Notebooks/DermaLLM_old_backup/DermaLLM/data/'

td_date = datetime.datetime.now().strftime("%m_%d_%Y")

# %%
# Import reviews table
reviews_df = pd.read_pickle(data_dir + "reviews_info.pkl")
# Drop extra index column
reviews_df.drop(['Unnamed: 0'], inplace=True, axis=1)
print(reviews_df.shape)
# Drop initial duplicates
reviews_df.drop_duplicates(inplace=True)
print(reviews_df.shape)
print(reviews_df.columns)
reviews_df
# Out:
# (1094411, 18)
# (1094187, 18)
# Index(['author_id', 'rating', 'is_recommended', 'helpfulness',
#        'total_feedback_count', 'total_neg_feedback_count',
#        'total_pos_feedback_count', 'submission_time', 'review_text',
#        'review_title', 'skin_tone', 'eye_color', 'skin_type', 'hair_color',
#        'product_id', 'product_name', 'brand_name', 'price_usd'],
#       dtype='object')
#          author_id  rating  is_recommended  helpfulness  total_feedback_count  \
# 0       1741593524       5             1.0          1.0                     2
# 1      31423088263       1             0.0          NaN                     0
# 2       5061282401       5             1.0          NaN                     0
# 3       6083038851       5             1.0          NaN                     0
# 4      47056667835       5             1.0          NaN                     0
# ...            ...     ...             ...          ...                   ...
# 49972   2276253200       5             1.0          NaN                     0
# 49973  28013163278       5             1.0          NaN                     0
# 49974   1539813076       5             1.0          NaN                     0
# 49975   5595682861       5             1.0          NaN                     0
# 49976  27666075558       5             1.0          NaN                     0
#
#        total_neg_feedback_count  total_pos_feedback_count submission_time  \
# 0                             0                         2      2023-02-01
# 1                             0                         0      2023-03-21
# 2                             0                         0      2023-03-21
# 3                             0                         0      2023-03-20
# 4                             0                         0      2023-03-20
# ...                         ...                       ...             ...
# 49972                         0                         0      2023-03-13
# 49973                         0                         0      2023-03-13
# 49974                         0                         0      2023-03-13
# 49975                         0                         0      2023-03-13
# 49976                         0                         0      2023-03-13
#
#                                              review_text  \
# 0      I use this with the Nudestix “Citrus Clean Bal...
# 1      I bought this lip mask after reading the revie...
# 2      My review title says it all! I get so excited ...
# 3      I’ve always loved this formula for a long time...
# 4      If you have dry cracked lips, this is a must h...
# ...                                                  ...
# 49972  Consider salicylic acid your secret weapon for...
# 49973  I’ve been using this as my only moisturizer fo...
# 49974  I got breakouts whenever it’s my time of month...
# 49975  I love this!!! I don’t get actual acne just an...
# 49976  I have never tried anything from StriVectin bu...
#
#                            review_title skin_tone eye_color    skin_type  \
# 0      Taught me how to double cleanse!       NaN     brown          dry
# 1                          Disappointed       NaN       NaN          NaN
# 2                  New Favorite Routine     light     brown          dry
# 3       Can't go wrong with any of them       NaN     brown  combination
# 4                       A must have !!!     light     hazel  combination
# ...                                 ...       ...       ...          ...
# 49972                               NaN      fair     brown  combination
# 49973                               NaN       NaN      blue  combination
# 49974                               NaN     light      blue  combination
# 49975                               NaN      fair     hazel         oily
# 49976                   Amazing Product     light     green       normal
#
#       hair_color product_id  \
# 0          black    P504322
# 1            NaN    P420652
# 2         blonde    P420652
# 3          black    P420652
# 4            NaN    P420652
# ...          ...        ...
# 49972        NaN    P505392
# 49973     blonde    P505392
# 49974     blonde    P505392
# 49975        NaN    P505392
# 49976        NaN    P505392
#
#                                             product_name  brand_name  \
# 0                         Gentle Hydra-Gel Face Cleanser    NUDESTIX
# 1      Lip Sleeping Mask Intense Hydration with Vitam...     LANEIGE
# 2      Lip Sleeping Mask Intense Hydration with Vitam...     LANEIGE
# 3      Lip Sleeping Mask Intense Hydration with Vitam...     LANEIGE
# 4      Lip Sleeping Mask Intense Hydration with Vitam...     LANEIGE
# ...                                                  ...         ...
# 49972  Multi Action Clear Acne Clearing Treatment Lot...  StriVectin
# 49973  Multi Action Clear Acne Clearing Treatment Lot...  StriVectin
# 49974  Multi Action Clear Acne Clearing Treatment Lot...  StriVectin
# 49975  Multi Action Clear Acne Clearing Treatment Lot...  StriVectin
# 49976  Multi Action Clear Acne Clearing Treatment Lot...  StriVectin
#
#        price_usd
# 0           19.0
# 1           24.0
# 2           24.0
# 3           24.0
# 4           24.0
# ...          ...
# 49972       49.0
# 49973       49.0
# 49974       49.0
# 49975       49.0
# 49976       49.0
#
# [1094187 rows x 18 columns]

# %%
numerical_cols = reviews_df.select_dtypes(include='number').columns.tolist()
categorical_cols = reviews_df.select_dtypes(include='object').columns.tolist()

# %%
variable_summary, cat_vars_summary, cont_vars_summary, df_corr = data_summary(reviews_df, cat_cols = categorical_cols , num_cols = numerical_cols)
# Out:
# Data shape:  (1094187, 18)
# Data columns:  Index(['author_id', 'rating', 'is_recommended', 'helpfulness',
#        'total_feedback_count', 'total_neg_feedback_count',
#        'total_pos_feedback_count', 'submission_time', 'review_text',
#        'review_title', 'skin_tone', 'eye_color', 'skin_type', 'hair_color',
#        'product_id', 'product_name', 'brand_name', 'price_usd'],
#       dtype='object')

# %%
variable_summary
# Out:
#                     variable data_type  hit_rate
# 0                  author_id    object  1.000000
# 1                     rating     int64  1.000000
# 2             is_recommended   float64  0.846577
# 3                helpfulness   float64  0.486865
# 4       total_feedback_count     int64  1.000000
# 5   total_neg_feedback_count     int64  1.000000
# 6   total_pos_feedback_count     int64  1.000000
# 7            submission_time    object  1.000000
# 8                review_text    object  0.998680
# 9               review_title    object  0.716113
# 10                 skin_tone    object  0.844242
# 11                 eye_color    object  0.808525
# 12                 skin_type    object  0.898144
# 13                hair_color    object  0.792861
# 14                product_id    object  1.000000
# 15              product_name    object  1.000000
# 16                brand_name    object  1.000000
# 17                 price_usd   float64  1.000000

# %%
cat_vars_summary
# Out:
#         variable_name            unique_values counts
# 0           author_id               1696370280    234
# 1           author_id               1288462295    171
# 2           author_id               5060164185    132
# 3           author_id               2330399812    131
# 4           author_id               7375781965    130
# ...               ...                      ...    ...
# 1922353    brand_name               TWEEZERMAN     38
# 1922354    brand_name          Soleil Toujours     37
# 1922355    brand_name  Anastasia Beverly Hills     27
# 1922356    brand_name                  caliray     24
# 1922357    brand_name              Erno Laszlo      2
#
# [1922358 rows x 3 columns]

# %%
cont_vars_summary
# Out:
#     stats        rating  is_recommended    helpfulness  total_feedback_count  \
# 0   count  1.094187e+06   926314.000000  532721.000000          1.094187e+06
# 1    mean  4.299077e+00        0.839954       0.767891          4.177699e+00
# 2     std  1.149490e+00        0.366649       0.317057          2.271751e+01
# 3     min  1.000000e+00        0.000000       0.000000          0.000000e+00
# 4     10%  2.000000e+00        0.000000       0.200000          0.000000e+00
# 5     20%  4.000000e+00        1.000000       0.500000          0.000000e+00
# 6     25%  4.000000e+00        1.000000       0.653846          0.000000e+00
# 7     50%  5.000000e+00        1.000000       0.928571          0.000000e+00
# 8     75%  5.000000e+00        1.000000       1.000000          3.000000e+00
# 9     90%  5.000000e+00        1.000000       1.000000          1.000000e+01
# 10    95%  5.000000e+00        1.000000       1.000000          1.700000e+01
# 11    99%  5.000000e+00        1.000000       1.000000          4.800000e+01
# 12    max  5.000000e+00        1.000000       1.000000          5.464000e+03
#
#     total_neg_feedback_count  total_pos_feedback_count     price_usd
# 0               1.094187e+06              1.094187e+06  1.094187e+06
# 1               8.948132e-01              3.282886e+00  4.900874e+01
# 2               5.289416e+00              1.967678e+01  4.004439e+01
# 3               0.000000e+00              0.000000e+00  3.000000e+00
# 4               0.000000e+00              0.000000e+00  1.400000e+01
# 5               0.000000e+00              0.000000e+00  2.200000e+01
# 6               0.000000e+00              0.000000e+00  2.500000e+01
# 7               0.000000e+00              0.000000e+00  3.900000e+01
# 8               1.000000e+00              3.000000e+00  6.200000e+01
# 9               2.000000e+00              8.000000e+00  8.900000e+01
# 10              4.000000e+00              1.300000e+01  1.100000e+02
# 11              1.300000e+01              3.800000e+01  2.250000e+02
# 12              1.159000e+03              5.050000e+03  1.900000e+03

# %%
# Quick check - how many duplicates exist?
print(f"Original rows: {len(reviews_df)}")
print(f"Unique rows (all columns): {len(reviews_df.drop_duplicates())}")
print(f"Duplicate rows: {len(reviews_df) - len(reviews_df.drop_duplicates())}")

# Check individual column uniqueness
print("\nUniqueness per column:")
for col in reviews_df.columns:
    unique_pct = (reviews_df[col].nunique() / len(reviews_df)) * 100
    print(f"{col}: {reviews_df[col].nunique()} unique ({unique_pct:.1f}%)")
# Out:
# Original rows: 1094187
# Unique rows (all columns): 1094187
# Duplicate rows: 0
#
# Uniqueness per column:
# author_id: 578653 unique (52.9%)
# rating: 5 unique (0.0%)
# is_recommended: 2 unique (0.0%)
# helpfulness: 3767 unique (0.3%)
# total_feedback_count: 676 unique (0.1%)
# total_neg_feedback_count: 259 unique (0.0%)
# total_pos_feedback_count: 590 unique (0.1%)
# submission_time: 5317 unique (0.5%)
# review_text: 969419 unique (88.6%)
# review_title: 364105 unique (33.3%)
# skin_tone: 14 unique (0.0%)
# eye_color: 6 unique (0.0%)
# skin_type: 4 unique (0.0%)
# hair_color: 7 unique (0.0%)
# product_id: 2351 unique (0.2%)
# product_name: 2334 unique (0.2%)
# brand_name: 142 unique (0.0%)
# price_usd: 221 unique (0.0%)

# %%
check = reviews_df[reviews_df['product_id']=='P377368']
check
# Out:
#          author_id  rating  is_recommended  helpfulness  total_feedback_count  \
# 91964   1568079543       5             1.0     1.000000                     4
# 91965   5718657317       5             1.0     0.714286                     7
# 91966  32245620971       2             0.0     0.812500                    16
# 91967   2500599340       2             0.0     0.772727                    22
# 91968   2708670599       5             1.0     0.837838                    37
# ...            ...     ...             ...          ...                   ...
# 92373   5223641660       5             NaN     0.666667                     6
# 92374   1299032380       5             NaN     1.000000                    23
# 92375   5143711471       5             NaN     0.888889                     9
# 92376   5442226740       5             NaN     0.833333                    18
# 92377   1011222666       5             NaN     0.888889                    90
#
#        total_neg_feedback_count  total_pos_feedback_count submission_time  \
# 91964                         0                         4      2022-08-12
# 91965                         2                         5      2022-02-14
# 91966                         3                        13      2021-12-26
# 91967                         5                        17      2021-07-12
# 91968                         6                        31      2021-04-18
# ...                         ...                       ...             ...
# 92373                         2                         4      2013-02-24
# 92374                         0                        23      2013-02-23
# 92375                         1                         8      2013-02-21
# 92376                         3                        15      2013-02-07
# 92377                        10                        80      2013-01-18
#
#                                              review_text  \
# 91964  I have problem skin and breakout easy.  After ...
# 91965  I was very skeptical about this one but I had ...
# 91966  It feels nice on skin, easy to use, but I hone...
# 91967  If you have pitted (scooped out) scars, this w...
# 91968  Using since 1/21/21. Today is 4/17/21. On seco...
# ...                                                  ...
# 92373  Cannot believe it, but it’s really diminishing...
# 92374  Had my 2nd c-section 9 months ago and within 3...
# 92375  as stated, within the last three weeks two 2“-...
# 92376  I have a few scars from acne and this product ...
# 92377  I recently had Mohs surgery for basil cell car...
#
#                                         review_title    skin_tone eye_color  \
# 91964                             It changed my life  lightMedium     brown
# 91965                                 miracle worker        light     brown
# 91966                                   Doesn't work    fairLight     hazel
# 91967             For Pitted Scars -- This Ain't It.        light     brown
# 91968  it’s working with time,patience and a regimen        light     brown
# ...                                              ...          ...       ...
# 92373                            It really works !!!          NaN       NaN
# 92374                      Great for surgical scars!          NaN       NaN
# 92375                                  it's working!          NaN       NaN
# 92376                                        Love it          NaN       NaN
# 92377                  A product that actually WORKS          NaN       NaN
#
#          skin_type hair_color product_id                   product_name  \
# 91964  combination      black    P377368  D-Scar Scar Diminishing Serum
# 91965  combination      brown    P377368  D-Scar Scar Diminishing Serum
# 91966         oily     auburn    P377368  D-Scar Scar Diminishing Serum
# 91967          dry      brown    P377368  D-Scar Scar Diminishing Serum
# 91968          dry     blonde    P377368  D-Scar Scar Diminishing Serum
# ...            ...        ...        ...                            ...
# 92373          NaN        NaN    P377368  D-Scar Scar Diminishing Serum
# 92374          NaN        NaN    P377368  D-Scar Scar Diminishing Serum
# 92375       normal        NaN    P377368  D-Scar Scar Diminishing Serum
# 92376          NaN        NaN    P377368  D-Scar Scar Diminishing Serum
# 92377          dry        NaN    P377368  D-Scar Scar Diminishing Serum
#
#             brand_name  price_usd
# 91964  Kate Somerville       56.0
# 91965  Kate Somerville       56.0
# 91966  Kate Somerville       56.0
# 91967  Kate Somerville       56.0
# 91968  Kate Somerville       56.0
# ...                ...        ...
# 92373  Kate Somerville       56.0
# 92374  Kate Somerville       56.0
# 92375  Kate Somerville       56.0
# 92376  Kate Somerville       56.0
# 92377  Kate Somerville       56.0
#
# [414 rows x 18 columns]

# %%
summarize(check,['product_id'], numerical_cols)
# Out:
#   product_id_  rating_Min  rating_Max  rating_Mean  rating_Sum  \
# 0     P377368           1           5      4.05314        1678
#
#    is_recommended_Min  is_recommended_Max  is_recommended_Mean  \
# 0                 0.0                 1.0                  0.7
#
#    is_recommended_Sum  helpfulness_Min  helpfulness_Max  helpfulness_Mean  \
# 0                84.0              0.0              1.0          0.642623
#
#    helpfulness_Sum  total_feedback_count_Min  total_feedback_count_Max  \
# 0       222.990276                         0                       253
#
#    total_feedback_count_Mean  total_feedback_count_Sum  \
# 0                  10.321256                      4273
#
#    total_neg_feedback_count_Min  total_neg_feedback_count_Max  \
# 0                             0                            79
#
#    total_neg_feedback_count_Mean  total_neg_feedback_count_Sum  \
# 0                       1.934783                           801
#
#    total_pos_feedback_count_Min  total_pos_feedback_count_Max  \
# 0                             0                           235
#
#    total_pos_feedback_count_Mean  total_pos_feedback_count_Sum  price_usd_Min  \
# 0                       8.386473                          3472           56.0
#
#    price_usd_Max  price_usd_Mean  price_usd_Sum
# 0           56.0            56.0        23184.0

# %%
c2 = reviews_df.groupby(['product_id']).agg({'author_id':'nunique','review_text':'nunique'}).reset_index()
c2[c2['product_id']=='P377368']

# There should be 355 reviews, thus 355 total feedback for this single product
# However total feedback count sum goes to 4273, column is not reliable
# We will derive our own during sentiment analysis, safe to aggregate excluding these columns and avoid duplicates
# Out:
#     product_id  author_id  review_text
# 106    P377368        354          355

# %%
# Checking to see if duplicated author_id are legit

author_counts = check['author_id'].value_counts()

# Find author_ids that appear exactly twice
duplicate_authors = author_counts[author_counts == 2].index

# View only those rows
check[check['author_id'].isin(duplicate_authors)]

# Each duplicated author id correspond to a unique review, good to go
# Out:
#         author_id  rating  is_recommended  helpfulness  total_feedback_count  \
# 92236     8274447       5             NaN          NaN                     0
# 92247     8274447       4             NaN     0.954545                    22
# 92251  2512400640       5             NaN          NaN                     0
# 92274  2512400640       3             NaN     0.000000                     2
#
#        total_neg_feedback_count  total_pos_feedback_count submission_time  \
# 92236                         0                         0      2014-05-13
# 92247                         1                        21      2014-04-11
# 92251                         0                         0      2014-03-26
# 92274                         2                         0      2013-12-26
#
#                                              review_text  \
# 92236  This product is really helping my (new) scar f...
# 92247  I wrote an earlier review re: this product. Th...
# 92251  I got a sample of this and i wish i had more c...
# 92274  I got this as a free sample (glad i didnt spen...
#
#                   review_title skin_tone eye_color    skin_type hair_color  \
# 92236  Scar already responding       NaN       NaN  combination        NaN
# 92247   Kate Somerville D-Scar       NaN       NaN  combination        NaN
# 92251                 It works       NaN       NaN         oily        NaN
# 92274                  Okay...       NaN       NaN         oily        NaN
#
#       product_id                   product_name       brand_name  price_usd
# 92236    P377368  D-Scar Scar Diminishing Serum  Kate Somerville       56.0
# 92247    P377368  D-Scar Scar Diminishing Serum  Kate Somerville       56.0
# 92251    P377368  D-Scar Scar Diminishing Serum  Kate Somerville       56.0
# 92274    P377368  D-Scar Scar Diminishing Serum  Kate Somerville       56.0

# %% [markdown]
# ### Clean up duplicates

# %%
reviews_df_clean = reviews_df.copy(deep=True)
print(reviews_df_clean.shape)

# Columns to groupby, they will become the key to unique level in our data
key_cols = [i for i in reviews_df.columns if i not in ['helpfulness', 'total_feedback_count',	'total_neg_feedback_count',	'total_pos_feedback_count']]

# Instead of droping feedback columns altogether, sum up to the review level
reviews_df_clean = reviews_df_clean.groupby(key_cols).agg({'helpfulness':'mean', 'total_feedback_count':'sum', 'total_pos_feedback_count':'sum','total_neg_feedback_count':'sum'}).reset_index()
print(reviews_df_clean.shape)
reviews_df_clean
# Out:
# (1094187, 18)
# (581785, 18)
#               author_id  rating  is_recommended submission_time  \
# 0                538863       1             0.0      2018-11-01
# 1                561736       5             1.0      2018-07-28
# 2                561736       5             1.0      2018-07-28
# 3                602980       5             1.0      2018-10-03
# 4                696309       5             1.0      2019-06-17
# ...                 ...     ...             ...             ...
# 581780   orderGen270100       5             1.0      2019-02-28
# 581781    orderGen39837       5             1.0      2018-05-18
# 581782    orderGen39837       5             1.0      2020-08-24
# 581783    orderGen51156       5             1.0      2020-02-10
# 581784  orderGen5563740       3             0.0      2018-04-11
#
#                                               review_text  \
# 0       One use and into the trash this went. I woke u...
# 1       This is my nightly hero.  It is the one facial...
# 2       This is my nightly hero.  It is the one facial...
# 3       This has become a must have addition to my mor...
# 4       Well, I was a skeptic, but after trying a samp...
# ...                                                   ...
# 581780  I have dry sensitive combination skin and my f...
# 581781  This is great for fine lines! I’ve never revie...
# 581782  I got a facial and was told I have beautiful s...
# 581783  Nice cooling sensation once applied to the ski...
# 581784  I got the 7 day free sample kit of this serum ...
#
#                                              review_title    skin_tone  \
# 0                                            one and done         fair
# 1                                                Awesome!        light
# 2                                                Awesome!        light
# 3                                            Brain Must!!  lightMedium
# 4                               replacing my other serums  lightMedium
# ...                                                   ...          ...
# 581780  Can’t beat the price and you can see the resul...         fair
# 581781                 Actually working on my fine lines!        light
# 581782                                  Love this product        light
# 581783                           cooling and moisturizing  lightMedium
# 581784                                   Jury's still out         fair
#
#        eye_color    skin_type hair_color product_id  \
# 0           blue  combination     blonde    P420652
# 1           blue  combination     blonde    P421998
# 2           blue  combination     blonde    P445951
# 3           blue  combination     blonde    P423159
# 4          brown          dry      brown    P444222
# ...          ...          ...        ...        ...
# 581780      blue  combination     blonde    P427419
# 581781     green       normal     blonde    P429515
# 581782     green       normal     blonde    P456418
# 581783     brown  combination      black    P433443
# 581784     brown       normal      brown    P428100
#
#                                              product_name          brand_name  \
# 0       Lip Sleeping Mask Intense Hydration with Vitam...             LANEIGE
# 1       Midnight Recovery Concentrate Moisturizing Fac...  Kiehl's Since 1851
# 2       Midnight Recovery Concentrate Moisturizing Fac...  Kiehl's Since 1851
# 3                                              Brain Dust          Moon Juice
# 4                   Luxury Beauty Serum Calming Treatment   Saint Jane Beauty
# ...                                                   ...                 ...
# 581780            Hyaluronic Acid 2% + B5 Hydrating Serum        The Ordinary
# 581781                        C-Tango Vitamin C Eye Cream      Drunk Elephant
# 581782        Wild Rose Night-Brightening Sleeping Facial              KORRES
# 581783                            Aqua Bomb Sleeping Mask               belif
# 581784                     Potent-C Vitamin C Power Serum   Peter Thomas Roth
#
#         price_usd  helpfulness  total_feedback_count  \
# 0            24.0          NaN                     0
# 1            56.0     0.833333                     6
# 2            30.0     0.833333                     6
# 3            38.0     1.000000                     1
# 4           125.0     1.000000                    30
# ...           ...          ...                   ...
# 581780       15.7          NaN                     0
# 581781       64.0     0.250000                     8
# 581782       50.0     0.900000                    10
# 581783       38.0     0.000000                     1
# 581784      105.0     0.800000                    10
#
#         total_pos_feedback_count  total_neg_feedback_count
# 0                              0                         0
# 1                              5                         1
# 2                              5                         1
# 3                              1                         0
# 4                             30                         0
# ...                          ...                       ...
# 581780                         0                         0
# 581781                         2                         6
# 581782                         9                         1
# 581783                         0                         1
# 581784                         8                         2
#
# [581785 rows x 18 columns]

# %%
reviews_df_clean.nunique()
# Out:
# author_id                   317168
# rating                           5
# is_recommended                   2
# submission_time               2029
# review_text                 509491
# review_title                282012
# skin_tone                       14
# eye_color                        6
# skin_type                        4
# hair_color                       7
# product_id                    2333
# product_name                  2317
# brand_name                     141
# price_usd                      220
# helpfulness                   2974
# total_feedback_count           581
# total_pos_feedback_count       517
# total_neg_feedback_count       219
# dtype: int64

# %% [markdown]
# ### Save full dataframe

# %%
reviews_df_clean.to_pickle(data_dir + f'reviews_data_clean_{td_date}.pkl')
